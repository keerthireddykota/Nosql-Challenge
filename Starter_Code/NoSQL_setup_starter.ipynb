# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# mongoimport --db uk_food --collection establishments --drop --file Starter_Code/Resources/establishments.json --jsonArray

# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
uk_food_db = mongo.uk_food

# %%
# review the collections in our new database
uk_food_db.list_collection_names()
# Out:
# ['establishments']

# %%
# review the collections in our new database

# %%
# review a document in the establishments collection
pprint(uk_food_db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6603a6feb964226d5313b4b7'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = uk_food_db.establishments

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours_rec = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
#establishments.delete_one(penang_flavours_rec)
result = establishments.insert_one(penang_flavours_rec)
result.inserted_id
# Out:
# ObjectId('6603ad108f7e1d6da4864f4b')

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one(penang_flavours_rec))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6603ad108f7e1d6da4864f4b'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
results = establishments.find({"BusinessType":"Restaurant/Cafe/Canteen"},{"BusinessTypeID":1,"BusinessType":1})
for rec in results:
    pprint(rec)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334acb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334acd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ace')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334acf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ad0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ad1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ad5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ada')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334adb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334adc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ae1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ae8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334aea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334aeb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334af6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334afb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334afd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334afe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334aff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b1a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b1c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b24')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b2f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b37')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b55')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b56')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b59')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b5a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b6e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b73')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b7a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b81')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b88')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b8d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334b98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ba0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ba1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ba2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bb6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bb7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bc7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bc9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bcf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bd9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334be1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334be8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334be9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bf1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bf4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334bfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c03')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c15')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c1c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c29')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c33')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c38')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c4a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c51')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c55')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c59')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c69')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c73')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c7d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c8d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c96')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334c9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ca0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ca7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334caa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334cc2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334cd5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334cde')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ce9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ced')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334cef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334cf2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334cf6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d2f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d34')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d71')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d78')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d8f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334d91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334da3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334da6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334da7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dbb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dbd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dc0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dc6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dd8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ddd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ddf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334de3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334de6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334df6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334df7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334dff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e38')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e3e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e51')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e52')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e5a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e5f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e63')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e69')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e6e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e76')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e9d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334e9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ea5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ea7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ea8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334eaa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334eb6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334eb7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334eb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ec9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ecc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ecd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ed0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334edb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ede')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ee3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ee6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ef3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334eff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f1a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f3e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f43')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f49')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f4a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f4e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f51')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f52')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f5c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f68')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f69')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f6a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f72')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f87')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f88')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f8f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334f9d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fa1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fa2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fa3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334faa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fb1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fbb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fbd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fbe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fdb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fe1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fe3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fe7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334fe9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ff1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ff3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ff9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ffc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921334ffd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335000')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335002')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133500a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133500c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133500e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335014')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335017')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133501a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133501d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335021')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335022')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335025')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335026')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335027')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335028')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335029')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133502b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133502c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133502d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335030')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335031')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335032')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335033')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335036')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335037')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335038')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133503a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133503d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133503e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133503f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335040')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335042')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335044')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335047')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133504a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133504e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335050')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335052')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335053')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335054')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335055')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335057')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133505a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133505f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335063')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335066')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335068')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133506c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133506e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335070')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335076')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133507a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335082')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335091')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac55069093921335096')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133509c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac5506909392133509f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac550690939213350ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e418')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e419')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e41a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e41b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e41d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e422')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e423')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e427')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e429')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e42d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e431')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e439')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e43f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e441')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e442')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e443')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e445')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e447')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e449')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e44b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e44c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e44d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e44e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e44f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e451')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e452')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e454')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e456')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e457')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e45e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e460')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e461')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e462')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e464')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e467')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e46c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e46d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e470')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e477')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e479')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e47c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e47d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e47f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e485')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e489')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e492')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e493')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e494')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e498')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e4ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e501')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e506')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e507')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e50e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e50f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e51a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e51c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e51d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e51e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e522')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e52e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e530')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e53d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e547')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e549')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e54e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e557')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e55a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e55e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e563')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e568')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e569')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e56b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e56d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e56e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e579')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e57c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e57d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e57e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e580')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e581')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e584')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e585')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e589')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e58b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e58d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e58e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e58f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e593')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e594')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e595')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e598')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e59a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e59b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e59c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e59d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e59f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e5f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e600')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e604')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e610')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e611')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e613')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e61b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e61e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e628')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6603aac6506909392133e62d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('6603ad108f7e1d6da4864f4b')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(penang_flavours_rec,{'$set':{'BusinessTypeID':1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
penang_name = {"BusinessName":"Penang Flavours"}
pprint(establishments.find_one(penang_name,{'BusinessTypeID':1}))
# Out:
# {'BusinessTypeID': 1, '_id': ObjectId('6603ad108f7e1d6da4864f4b')}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({"LocalAuthorityName":"Dover"})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({"LocalAuthorityName":"Dover"})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
establishments.count_documents({"LocalAuthorityName":"Dover"})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': '16 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Mariner',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289560,
#  'LocalAuthorityBusinessID': 'PI/000039927',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2019-03-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6603aac55069093921334db2'),
#  'geocode': {'latitude': '51.08084', 'longitude': '1.188537'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289560',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.updateMany(
  { 'geocode'['latitude'] : { $type: 1 } },
  [{ $set: { 'geocode'['latitute']: { $toDecimal: "$'geocode'['latitute']" } } }]
)
# Out:
#   Cell In[40], line 3
#     { 'geocode'['latitude'] : { $type: 1 } },
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
pprint(establishments.find_one())
# Out:
# {'AddressLine1': '16 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Mariner',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289560,
#  'LocalAuthorityBusinessID': 'PI/000039927',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2019-03-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6603aac55069093921334db2'),
#  'geocode': {'latitude': '51.08084', 'longitude': '1.188537'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289560',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %%
# Check that the coordinates and rating value are now numbers
